# %%
import numpy as np
import pandas as pd

# %%
from utils import *

# %%
train_load,test_load = load_dataset(True)
# Out:
# Generating train and test loaders:
# Train Dataset download complete
# Train Dataset download complete
# Train Dataset download complete
# Train Dataset download complete
# __________
# Visualizing few downloaded images
